# %% [markdown]
# # **과제2 : 챗봇 만들기2**

# %% [markdown]
# ## 0.미션
#
# * 예비 에이블러들을 위한 QA 챗봇 모델 만들기2
#     * Vector DB에 데이터 추가하기
#     * Retriever, memory, LLM를 연결하기
#     * 실행시 이력 DB 생성하고 기록하기
#     * test

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### (1) 라이브러리 Import

# %%
import pandas as pd
import numpy as np
import os
import sqlite3
from datetime import datetime

import openai

from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, Document
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA, ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ### (2) OpenAI API Key 확인
# * 환경변수로 등록된 Key 확인하기

# %%
# 환경변수에서 키 불러오기
api_key = os.getenv('OPENAI_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 환경변수에서 키 불러오기
# ----> 2 api_key = os.getenv('OPENAI_API_KEY')
#
# NameError: name 'os' is not defined

# %% [markdown]
# * 만약 환경변수 키 설정이 잘 안된다면 아래 코드셀의 주석을 해제하고, 자신의 api key를 입력하고 실행
#     * 아래 코드는 키 지정을 **임시**로 수행함.
#     * 파이썬 파일(.ipynb, .py)안에서 매번 수행해야 함.

# %% [markdown]
# ## **2.Vector DB 만들기**

# %% [markdown]
# * 데이터 로딩
#     * 1일차에서 제공한 csv 파일의 구조를 그대로 이용
#     * 에이블스쿨 홈페이지 FAQ 데이터 수집(https://aivle.kt.co.kr/home/brd/faq/main?mcd=MC00000056)
#         * 모든 질문을 csv 형태로 저장
#     * 데이터프레임으로 저장하기

# %%
import pandas as pd

df = pd.read_csv('onsemi_qa.csv', encoding='utf-8')
df.tail()
# Out:
#       구분                                                 QA
# 25   일자리  노인 일자리 및 사회활동 지원사업에 대해서 문의하고 싶은데 전화번호가 어떻게 돼? ...
# 26  의료지원  노인을 위한 치과 치료에 대한 지원 사업이 있어? 네 있습니다. 보건복지부 기초의료...
# 27  의료지원  의료급여 틀니, 치과임플란트 지원 사업의 지원 대상자이 어떻게 되나요? 의료급여 틀...
# 28  의료지원  의료급여 틀니, 치과 임플란트 지원 사업 신청 방법은 어떻게 돼? 틀니, 치과임플란...
# 29  의료지원  의료급여 틀니, 치과 임플란트 지원 사업에 대해서 문의하고 싶은데 전화번호가 어떻게...

# %% [markdown]
# * 벡터 데이터베이스
#     * 1일차 벡터 데이터베이스를 그대로 이용
#         * Embedding 모델 : text-embedding-ada-002
#         * DB 경로 : ./db

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

database = Chroma(persist_directory="./database", 
                    embedding_function = embeddings  
)

# %% [markdown]
# * 데이터 입력
#     * 기존 입력을 모두 제거하고 추가 사항만 모두 입력
#     * meta data로 '구분' 칼럼 값 추가하기

# %%
database.get()
# Out:
# {'ids': ['009e03eb-2090-42ab-a7b2-107079640e85',
#   '125e1679-8611-4205-80d0-1609ed16066a',
#   '1b18f7c7-b629-4ef5-b1e3-657abf255eb5',
#   '3010db9b-ef6c-495b-b1bb-01e7fad8d872',
#   '383297a4-3536-44e4-8922-8abd68b1d12a',
#   '39bfb38d-0ebc-4a7a-8fba-2f6ba762dd97',
#   '39ffd208-5dbc-4509-bacd-ebd87fd46753',
#   '4768a330-cea0-4037-8303-0f8b3b991978',
#   '4aba8a27-823a-4173-a17d-e35d962d9a5e',
#   '4ad8aca0-0f14-40f4-9839-797554ae885b',
#   '4e37312f-30de-4e3e-829e-fdc0102ee742',
#   '53c10b74-2a9b-4a4e-92d2-5218822157c2',
#   '58d04d77-6061-4eed-9e5f-e928faa488f0',
#   '5b028b07-1953-426e-8fad-0087b175c5b3',
#   '70898971-7107-4c6b-8e3b-d09d81c090b5',
#   '708a837b-0e82-4c60-b1d1-74d469b223b4',
#   '76aee80e-1021-4767-8b09-be1413203b45',
#   '830a5180-7c81-4309-8296-3f9726b45812',
#   '845f1906-adf8-4bb4-8a5a-3f0070e6b8e8',
#   '894904c1-f3d2-4fd7-8349-9e3e6597e392',
#   '8a20e186-39b6-4416-b741-ac4ffa43b223',
#   '8a49aa9b-496b-47db-b007-1b7db6bdb13d',
#   '916f5540-2848-4a38-bfe8-c776d0b48dc6',
#   'b1807caf-7be1-44c9-9340-3451cbb705ce',
#   'b7570096-43b4-49c9-bb50-efaf9645659d',
#   'b8c6a7c2-1f74-4d00-a477-ec469560e058',
#   'c6539c12-6d6e-43c7-9f08-90b8ef8599a4',
#   'd92ea955-016c-4ab9-87d1-897a56455e8c',
#   'e5286ca2-28f4-4ac1-923f-77efb2e08fbc',
#   'e7602d0c-a8ed-47ae-9aac-99097c909b2a'],
#  'embeddings': None,
#  'metadatas': [{'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '일자리'},
#   {'구분': '질문'},
#   {'구분': '교통지원'},
#   {'구분': '질문'},
#   {'구분': '일자리'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '교통지원'},
#   {'구분': '교통지원'},
#   {'구분': '일자리'},
#   {'구분': '의료지원'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '교통지원'},
#   {'구분': '질문'},
#   {'구분': '의료지원'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '일자리'},
#   {'구분': '의료지원'},
#   {'구분': '의료지원'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '질문'},
#   {'구분': '질문'}],
#  'documents': ['결제 방법은 어떤 것들이 있나요? 신용카드/체크카드 결제 및 가상계좌 결제가 가능합니다.',
#   '어르신의 건강 정보는 안전하게 관리되나요? 암호화되어 안전하게 관리되고있습니다.',
#   '노인 일자리 및 사회활동 지원사업의 신청방법은 어떻게 돼? 방법은 2가지가 있습니다. 첫 번째 방법은 지방자치단체별 행정복지센터(구, 동사무소)나, 가까운 노인일자리 수행기관을 방문하여 신청이 가능합니다. 두 번째 방법은 노인일자리 여기(www.seniorro.or.ke), 복지로(www.bokjiro.go.kr), 정부24(www.gov.kr))을 통해 온라인 신청이 가능합니다. - 복지로 온라인신청 경로 : 복지로 로그인 > 서비스 신청 > 민원서비스 신청 > 민원서비스 신청 > 노인일자리사업',
#   '서비스 사용 중 생기는 문제를 어떻게 신고하나요? 챗봇을 통한 답변이 나오지 않을 경우 온새미로 연락 부탁드립니다.',
#   '대중교통 지원에 대해서 문의 하고 싶은데 전화 번호가 뭐야?  K-패스 고객센터 : 031-427-4415, 국토교통부 : 1599-0001 입니다.',
#   '개인정보를 수정하려면 어떻게 해야 하나요? 마이페이지에서 수정 가능합니다.',
#   '노인 일자리 지원 사업이 있어? 네 있습니다. 보건복지부 노인지원과에서 담당하고 있는 노인일자리 및 사회활동 지원사업을 진행하고 있습니다. 이 사업으로 활기차고 건강한 노후생활을 영위할 수 있도록 다양한 일자리를 제공하고 사회활동을 지원하여 노인 복지 향상에 기여합니다.',
#   '특정 상품을 즐겨찾기에 추가할 수 있나요? 장바구니 기능이 있습니다.',
#   '어르신의 건강 상태를 어떻게 확인할 수 있나요? 보호자 페이지에 있는 대시보드에서 확인이 가능합니다.',
#   '대중교통 지원비 신청 방법은 어떻게 돼? 별도 신청 없이 직접 지원합니다. (단, K-패스 카드 발급 및 회원가입 필요)',
#   '대중교통 지원 해줘? 네 지원합니다. 월 15회 이상 대중교통 이용 비용의 일정비율에 대해 환급 지원합니다. 일반 20%, 청년(19~34세) 30%, 저소득 53% 환급 지원합니다.',
#   '노인 일자리 및 사회활동 지원사업에 대해서 문의하고 싶은데 전화번호가 어떻게 돼? 보건복지부 : 129, 한국노인인력개발원 : 1544-3388 입니다.',
#   '노인을 위한 치과 치료에 대한 지원 사업이 있어? 네 있습니다. 보건복지부 기초의료보장과에서 담당하고 있는 의료급여 틀니, 치과 임플란트 지원 사업을 진행하고 있습니다. 틀니 및 치과임플란트에 대하여 의료급여를 실시하여 65세 이상 노인 수급권자의 경제적 부담을 완화하고 구강건강 향상을 도모합니다.',
#   '커뮤니티에서 자주 묻는 질문은 어디서 확인할 수 있나요? 따로 FAQ페이지를 운영하고 있지 않습니다. 챗봇을 통한 답변이 나오지 않을 경우 온새미로 연락 부탁드립니다.',
#   '서비스 이용 요금은 어떻게 되나요? 무료로 사용 가능합니다.',
#   '대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통 이용자를 대상으로 지원합니다. 외국인 등록번호가 있는 외국인에 한해 회원가입 가능합니다. 외국인 등록번호로 거소사실 여부를 확인할 수 없다면, ""홈페이지""로 가입 가능합니다. ',
#   '어르신의 건강 정보 입력은 누가 할 수 있나요? 첫 가입시 보호자님이 작성후 봉사자가 관리합니다.',
#   '의료급여 틀니, 치과 임플란트 지원 사업 신청 방법은 어떻게 돼? 틀니, 치과임플란트 대상자 사전등록제를 운영합니다. 치과 병·의원에서 시술 전에 국민건강보험공단 등록시스템(요양기관 정보마당)을 통해 직접 등록합니다. 또는 의료급여 수급권자가 발급받은 틀니(치과임플란트) 등록신청서를 관할 시군구청 또는 읍면동에 방문하여 제출·등록 후 시술합니다.',
#   '어르신을 위해 어떤 상품을 주문할 수 있나요? 기본적인 생필품을 구매하실 수 있습니다.',
#   '다른 보호자들과 소통할 수 있는 방법이 있나요? 커뮤니티에서 소통 가능합니다.',
#   '주문한 상품의 배송 상태를 어떻게 확인하나요? 주문 내역에서 확인 가능합니다.',
#   '다른 가족 구성원도 계정을 만들 수 있나요? 가족 구성원 당 한 명만 계정 생성 가능합니다.',
#   '어르신 상태 업데이트 빈도는 어떻게 되나요? 월 4회 입니다.',
#   '노인 일자리 및 사회활동 지원사업의 지원대상은 어떻게 돼? 사회활동 지원사업 참여 조건에 부합하는 65세 이상 어르신을 지원하며, 일부 사업의 경우 60세 이상인 분들도 지원 가능합니다.',
#   '의료급여 틀니, 치과임플란트 지원 사업의 지원 대상자이 어떻게 되나요? 의료급여 틀니, 치과임플란트 지원 사업의 지원 대상은 만 65세 이상 의료급여 수급권자를 대상으로 합니다. 노인 틀니는 만 65세 이상 의료급여 수급권자, 치과임플란트는 만 65세 이상 부분 무치악 환자를 대상으로 합니다.',
#   '의료급여 틀니, 치과 임플란트 지원 사업에 대해서 문의하고 싶은데 전화번호가 어떻게 돼? 보건복지상담센터 : 129, 건강보험심사평가원 : 1644-2000, 보건복지부기초의료보장과 : 044-202-3098 입니다.',
#   '한 계정에 여러 명의 어르신을 등록할 수 있나요? 한 계정에 최대 2명을 등록할 수 있습니다.',
#   '등록된 어르신의 정보를 수정하려면 어떻게 해야 하나요? 마이페이지에서 등록된 어르신',
#   '주문한 상품을 반품하거나 교환할 수 있나요? 반품이나 교환은 어렵습니다. 하지만 제품 자체에 문제가 있는경우 환불처리 가능합니다.',
#   '구매 내역을 어디서 확인할 수 있나요? 주문 내역에서 확인 가능합니다.'],
#  'uris': None,
#  'data': None}

# %%
text_list = df['QA'].tolist()
metadata_list = df['구분'].tolist()

metadata = [{'구분': category} for category in metadata_list]

documents = [Document(page_content=text, metadata=meta) for text, meta in zip(text_list, metadata)]

database.add_documents(documents)
# Out:
# ['cb27339a-6023-4f71-b804-2a42daab5186',
#  '1a06edf3-a699-4868-b344-d1997841aad4',
#  '9f27dc6c-0cd5-4a97-8609-281d6cdfabcb',
#  'fa3ab2dc-05a6-485b-acb4-180013d629ca',
#  '76aa53d0-63a8-4af5-bb10-644ca8ebbea6',
#  '929387fd-e8c7-4a49-81f8-a01b91e823b2',
#  'cae32b06-2539-4b07-b51f-216ed0e91a6a',
#  'e3b1ccec-2bfe-4aef-be5b-2a2c5bab0f68',
#  '83c5a2bc-e1f4-48be-a77c-de76a41d3c62',
#  'f63c4c96-2a02-479c-bf3d-1e352c70d776',
#  'c4311b7c-f25c-40d9-b493-c777edbf98c2',
#  '02f96e79-d890-4cb4-aea3-b5404b4c1d33',
#  '417a5fe0-f043-49c1-a771-10b200bd6e75',
#  'dea45564-cdae-429f-bdac-13540e02938e',
#  'e87c3541-01e9-41b1-b745-95fc7b2eba81',
#  '93c5da5b-5dce-40f0-9789-e793637b3e46',
#  '9835e48e-b87a-4975-bc17-4d015346d541',
#  '9cb62f74-41c9-4ed0-9db7-ba69d89ba788',
#  '758f4acc-a16a-4c7c-839f-59544b1c2386',
#  '4dfae192-3c3b-4105-9adf-15ee63ceceab',
#  'a63b367c-89b4-4943-b09f-cbbe889f790f',
#  '3f57fdc9-e9d2-4c9a-be0c-a0501535c7ea',
#  '337ad730-62f9-492d-b376-5f492f817fc4',
#  'f0200552-5726-4421-81ad-3496539e34a0',
#  '3e16715a-7291-42be-b98b-44c2d50337e9',
#  'e6b1f024-0adb-4426-aa97-f9407a3b928a',
#  'feb2a6d7-919c-4430-956b-2895f30a9e84',
#  '1a4b323c-af29-4f31-bb5b-ba08e7158460',
#  'ec4be0b8-59dd-467f-a761-4c64c70fe762',
#  'b5c494f9-90bc-4c0c-ac85-677a6189d39c']

# %% [markdown]
# * 입력된 데이터 조회

# %%
dtt = database.get()
docu = pd.DataFrame(dtt)
docu[['metadatas','documents']]
# Out:
#          metadatas                                          documents
# 0     {'구분': '질문'}  결제 방법은 어떤 것들이 있나요? 신용카드/체크카드 결제 및 가상계좌 결제가 가능합니다.
# 1     {'구분': '질문'}       어르신의 건강 정보는 안전하게 관리되나요? 암호화되어 안전하게 관리되고있습니다.
# 2     {'구분': '질문'}       어르신의 건강 정보는 안전하게 관리되나요? 암호화되어 안전하게 관리되고있습니다.
# 3     {'구분': '질문'}  한 계정에 여러 명의 어르신을 등록할 수 있나요? 한 계정에 최대 2명을 등록할 수...
# 4   {'구분': '의료지원'}  의료급여 틀니, 치과임플란트 지원 사업의 지원 대상자이 어떻게 되나요? 의료급여 틀...
# 5    {'구분': '일자리'}  노인 일자리 및 사회활동 지원사업의 신청방법은 어떻게 돼? 방법은 2가지가 있습니다...
# 6     {'구분': '질문'}  서비스 사용 중 생기는 문제를 어떻게 신고하나요? 챗봇을 통한 답변이 나오지 않을 ...
# 7    {'구분': '일자리'}  노인 일자리 지원 사업이 있어? 네 있습니다. 보건복지부 노인지원과에서 담당하고 있...
# 8   {'구분': '교통지원'}  대중교통 지원에 대해서 문의 하고 싶은데 전화 번호가 뭐야?  K-패스 고객센터 :...
# 9     {'구분': '질문'}          개인정보를 수정하려면 어떻게 해야 하나요? 마이페이지에서 수정 가능합니다.
# 10   {'구분': '일자리'}  노인 일자리 지원 사업이 있어? 네 있습니다. 보건복지부 노인지원과에서 담당하고 있...
# 11   {'구분': '일자리'}  노인 일자리 및 사회활동 지원사업의 신청방법은 어떻게 돼? 방법은 2가지가 있습니다...
# 12  {'구분': '교통지원'}  대중교통 지원에 대해서 문의 하고 싶은데 전화 번호가 뭐야?  K-패스 고객센터 :...
# 13    {'구분': '질문'}          개인정보를 수정하려면 어떻게 해야 하나요? 마이페이지에서 수정 가능합니다.
# 14    {'구분': '질문'}             특정 상품을 즐겨찾기에 추가할 수 있나요? 장바구니 기능이 있습니다.
# 15    {'구분': '질문'}  어르신의 건강 상태를 어떻게 확인할 수 있나요? 보호자 페이지에 있는 대시보드에서 ...
# 16  {'구분': '교통지원'}  대중교통 지원비 신청 방법은 어떻게 돼? 별도 신청 없이 직접 지원합니다. (단, ...
# 17  {'구분': '교통지원'}  대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통...
# 18  {'구분': '교통지원'}  대중교통 지원 해줘? 네 지원합니다. 월 15회 이상 대중교통 이용 비용의 일정비율...
# 19   {'구분': '일자리'}  노인 일자리 및 사회활동 지원사업에 대해서 문의하고 싶은데 전화번호가 어떻게 돼? ...
# 20  {'구분': '의료지원'}  노인을 위한 치과 치료에 대한 지원 사업이 있어? 네 있습니다. 보건복지부 기초의료...
# 21    {'구분': '질문'}  커뮤니티에서 자주 묻는 질문은 어디서 확인할 수 있나요? 따로 FAQ페이지를 운영하...
# 22    {'구분': '질문'}                  서비스 이용 요금은 어떻게 되나요? 무료로 사용 가능합니다.
# 23  {'구분': '교통지원'}  대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통...
# 24  {'구분': '교통지원'}  대중교통 지원 해줘? 네 지원합니다. 월 15회 이상 대중교통 이용 비용의 일정비율...
# 25    {'구분': '질문'}            구매 내역을 어디서 확인할 수 있나요? 주문 내역에서 확인 가능합니다.
# 26    {'구분': '질문'}  어르신의 건강 정보 입력은 누가 할 수 있나요? 첫 가입시 보호자님이 작성후 봉사자...
# 27  {'구분': '의료지원'}  의료급여 틀니, 치과 임플란트 지원 사업 신청 방법은 어떻게 돼? 틀니, 치과임플란...
# 28    {'구분': '질문'}  주문한 상품을 반품하거나 교환할 수 있나요? 반품이나 교환은 어렵습니다. 하지만 제...
# 29    {'구분': '질문'}   어르신을 위해 어떤 상품을 주문할 수 있나요? 기본적인 생필품을 구매하실 수 있습니다.
# 30    {'구분': '질문'}        다른 보호자들과 소통할 수 있는 방법이 있나요? 커뮤니티에서 소통 가능합니다.
# 31    {'구분': '질문'}        주문한 상품의 배송 상태를 어떻게 확인하나요? 주문 내역에서 확인 가능합니다.
# 32    {'구분': '질문'}  다른 가족 구성원도 계정을 만들 수 있나요? 가족 구성원 당 한 명만 계정 생성 가...
# 33    {'구분': '질문'}                 어르신 상태 업데이트 빈도는 어떻게 되나요? 월 4회 입니다.
# 34    {'구분': '질문'}             특정 상품을 즐겨찾기에 추가할 수 있나요? 장바구니 기능이 있습니다.
# 35    {'구분': '질문'}  서비스 사용 중 생기는 문제를 어떻게 신고하나요? 챗봇을 통한 답변이 나오지 않을 ...
# 36    {'구분': '질문'}  커뮤니티에서 자주 묻는 질문은 어디서 확인할 수 있나요? 따로 FAQ페이지를 운영하...
# 37    {'구분': '질문'}  어르신의 건강 정보 입력은 누가 할 수 있나요? 첫 가입시 보호자님이 작성후 봉사자...
# 38    {'구분': '질문'}     등록된 어르신의 정보를 수정하려면 어떻게 해야 하나요? 마이페이지에서 등록된 어르신
# 39  {'구분': '교통지원'}  대중교통 지원비 신청 방법은 어떻게 돼? 별도 신청 없이 직접 지원합니다. (단, ...
# 40   {'구분': '일자리'}  노인 일자리 및 사회활동 지원사업의 지원대상은 어떻게 돼? 사회활동 지원사업 참여 ...
# 41  {'구분': '의료지원'}  의료급여 틀니, 치과 임플란트 지원 사업에 대해서 문의하고 싶은데 전화번호가 어떻게...
# 42  {'구분': '의료지원'}  의료급여 틀니, 치과임플란트 지원 사업의 지원 대상자이 어떻게 되나요? 의료급여 틀...
# 43  {'구분': '의료지원'}  의료급여 틀니, 치과 임플란트 지원 사업에 대해서 문의하고 싶은데 전화번호가 어떻게...
# 44    {'구분': '질문'}        다른 보호자들과 소통할 수 있는 방법이 있나요? 커뮤니티에서 소통 가능합니다.
# 45    {'구분': '질문'}  한 계정에 여러 명의 어르신을 등록할 수 있나요? 한 계정에 최대 2명을 등록할 수...
# 46    {'구분': '질문'}        주문한 상품의 배송 상태를 어떻게 확인하나요? 주문 내역에서 확인 가능합니다.
# 47    {'구분': '질문'}                  서비스 이용 요금은 어떻게 되나요? 무료로 사용 가능합니다.
# 48    {'구분': '질문'}     등록된 어르신의 정보를 수정하려면 어떻게 해야 하나요? 마이페이지에서 등록된 어르신
# 49    {'구분': '질문'}  다른 가족 구성원도 계정을 만들 수 있나요? 가족 구성원 당 한 명만 계정 생성 가...
# 50    {'구분': '질문'}  결제 방법은 어떤 것들이 있나요? 신용카드/체크카드 결제 및 가상계좌 결제가 가능합니다.
# 51    {'구분': '질문'}  주문한 상품을 반품하거나 교환할 수 있나요? 반품이나 교환은 어렵습니다. 하지만 제...
# 52   {'구분': '일자리'}  노인 일자리 및 사회활동 지원사업에 대해서 문의하고 싶은데 전화번호가 어떻게 돼? ...
# 53    {'구분': '질문'}            구매 내역을 어디서 확인할 수 있나요? 주문 내역에서 확인 가능합니다.
# 54    {'구분': '질문'}                 어르신 상태 업데이트 빈도는 어떻게 되나요? 월 4회 입니다.
# 55  {'구분': '의료지원'}  의료급여 틀니, 치과 임플란트 지원 사업 신청 방법은 어떻게 돼? 틀니, 치과임플란...
# 56   {'구분': '일자리'}  노인 일자리 및 사회활동 지원사업의 지원대상은 어떻게 돼? 사회활동 지원사업 참여 ...
# 57    {'구분': '질문'}  어르신의 건강 상태를 어떻게 확인할 수 있나요? 보호자 페이지에 있는 대시보드에서 ...
# 58    {'구분': '질문'}   어르신을 위해 어떤 상품을 주문할 수 있나요? 기본적인 생필품을 구매하실 수 있습니다.
# 59  {'구분': '의료지원'}  노인을 위한 치과 치료에 대한 지원 사업이 있어? 네 있습니다. 보건복지부 기초의료...

# %% [markdown]
# ## **3.RAG+LLM모델**

# %% [markdown]
# * 모델 : ConversationalRetrievalChain
#     * LLM 모델 : gpt-3.5-turbo
#     * retriever : 벡터DB
#         * 유사도 높은 문서 3개 가져오도록 설정
#     * memory 사용
# * 요구사항
#     * 질문 history 관리를 위한 이력 저장 DB 생성
#         * DB 명 : db_chatlog
#         * 테이블 명 : history
#             * id INTEGER PRIMARY KEY : 이렇게 설정하면 자동증가 값으로 채워짐
#             * datetime TEXT : 질문시점 yyyy-mm-dd hh:mi:ss
#             * query TEXT : 질문
#             * sim1 REAL : 첫번째 문서의 유사도 점수
#             * sim2 REAL : 두번째 문서의 유사도 점수
#             * sim3 REAL : 세번째 문서의 유사도 점수
#             * answer TEXT : 답변
#         * 유사도 점수는 similarity_search_with_score 메서드를 이용해서 저장해야 함
#         * 질문과 답변이 진행될 때마다 history 테이블에 데이터 입력

# %% [markdown]
# * 관리용 DB, 테이블 생성

# %% [markdown]
# * 모델 선언

# %% [markdown]
# * 모델 사용 및 이력 확인

# %%
chat = ChatOpenAI(model="gpt-3.5-turbo")
k=3
retriever = database.as_retriever(search_kwargs={"k": k})

memory = ConversationBufferMemory(memory_key="chat_history", input_key="question", output_key="answer",
                                  return_messages=True)#대화가 시작될때 memory가 실행되어야 한다.

qa = ConversationalRetrievalChain.from_llm(llm=chat, retriever=retriever, memory=memory,
                                           return_source_documents=True,  output_key="answer")

path = './db_chatlog/chatlog.db'
conn = sqlite3.connect(path)

cursor = conn.cursor()

cursor.execute('''DROP TABLE IF EXISTS history''')

cursor.execute('''
CREATE TABLE IF NOT EXISTS history (
    id INTEGER PRIMARY KEY,
    datetime TEXT NOT NULL,
    query TEXT NOT NULL,
    sim1 REAL NOT NULL,
    sim2 REAL NOT NULL,
    sim3 REAL NOT NULL,
    answer TEXT NOT NULL
)
''')

conn.commit()
conn.close()

while True:
    query = input('질문 > ')
    query = query.strip()
    print(f'질문 : {query}')
    print('-' * 20)
    if len(query) == 0:
        break
    result = qa({"question": query})
    print(f'답변 : {result["answer"]}')
    print('=' * 50)
    
    dt = datetime.now()
    dt = dt.strftime('%Y-%m-%d %H:%M:%S')
    
    score = []
    result2 = database.similarity_search_with_score(query, k = k)
    for doc in result2:
        score.append(round(doc[1], 5))
        
    conn = sqlite3.connect(path)

    history_data = pd.DataFrame({'datetime': [dt],'query':[query],'sim1': [score[0]],'sim2': [score[1]],'sim3': [score[2]],'answer':[result["answer"]]})
    history_data.to_sql('history', conn, if_exists='append', index=False)
    
    d2 = pd.read_sql('SELECT * FROM history', conn)
    display(d2)
    print(memory.load_memory_variables({}))

    conn.close()
lod_df = d2
# Out:
# 질문 : 사용 금액은?
# --------------------
# 답변 : 무료로 사용 가능합니다.
# ==================================================
#    id             datetime    query     sim1     sim2     sim3         answer
# 0   1  2024-06-27 09:28:19  사용 금액은?  0.22124  0.22124  0.29529  무료로 사용 가능합니다.
# {'chat_history': [HumanMessage(content='사용 금액은?'), AIMessage(content='무료로 사용 가능합니다.')]}
# 질문 : 상태 업데이트 빈도는?
# --------------------
# 답변 : 월 4회입니다.
# ==================================================
#    id             datetime         query     sim1     sim2     sim3  \
# 0   1  2024-06-27 09:28:19       사용 금액은?  0.22124  0.22124  0.29529
# 1   2  2024-06-27 09:28:33  상태 업데이트 빈도는?  0.19596  0.19596  0.36448
#
#           answer
# 0  무료로 사용 가능합니다.
# 1       월 4회입니다.
# {'chat_history': [HumanMessage(content='사용 금액은?'), AIMessage(content='무료로 사용 가능합니다.'), HumanMessage(content='상태 업데이트 빈도는?'), AIMessage(content='월 4회입니다.')]}
# 질문 :
# --------------------

# %%
query = "지원자격은??"   # 질문할 문장
k = 3                      # 유사도 상위 k 개 문서 가져오기.

result = database.similarity_search_with_score(query, k = k) #← 데이터베이스에서 유사도가 높은 문서를 가져옴
print(result)
print('-'*50)
for doc in result:
    print(f"유사도 점수 : {round(doc[1], 5)}, 문서 내용: {doc[0].page_content}") # 문서 내용 표시
# Out:
# [(Document(page_content='대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통 이용자를 대상으로 지원합니다. 외국인 등록번호가 있는 외국인에 한해 회원가입 가능합니다. 외국인 등록번호로 거소사실 여부를 확인할 수 없다면, ""홈페이지""로 가입 가능합니다. ', metadata={'구분': '교통지원'}), 0.291273675140306), (Document(page_content='대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통 이용자를 대상으로 지원합니다. 외국인 등록번호가 있는 외국인에 한해 회원가입 가능합니다. 외국인 등록번호로 거소사실 여부를 확인할 수 없다면, ""홈페이지""로 가입 가능합니다. ', metadata={'구분': '교통지원'}), 0.291273675140306), (Document(page_content='어르신의 건강 정보 입력은 누가 할 수 있나요? 첫 가입시 보호자님이 작성후 봉사자가 관리합니다.', metadata={'구분': '질문'}), 0.3127854441394578)]
# --------------------------------------------------
# 유사도 점수 : 0.29127, 문서 내용: 대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통 이용자를 대상으로 지원합니다. 외국인 등록번호가 있는 외국인에 한해 회원가입 가능합니다. 외국인 등록번호로 거소사실 여부를 확인할 수 없다면, ""홈페이지""로 가입 가능합니다.
# 유사도 점수 : 0.29127, 문서 내용: 대중교통 지원 대상이 어떻게 돼? 만 19세 이상 국민 중 월 15회 이상 대중교통 이용자를 대상으로 지원합니다. 외국인 등록번호가 있는 외국인에 한해 회원가입 가능합니다. 외국인 등록번호로 거소사실 여부를 확인할 수 없다면, ""홈페이지""로 가입 가능합니다.
# 유사도 점수 : 0.31279, 문서 내용: 어르신의 건강 정보 입력은 누가 할 수 있나요? 첫 가입시 보호자님이 작성후 봉사자가 관리합니다.

# %%
display(log_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 display(log_df)
#
# NameError: name 'log_df' is not defined

# %%
# def process_query(query, k=3):
#     result = database.similarity_search_with_score(query, k=k)
#     sim1 = round(result[0][1], 5)
#     sim2 = round(result[1][1], 5)
#     sim3 = round(result[2][1], 5)
#     dt = datetime.now()    
#     dt = dt.strftime('%Y-%m-%d %H:%M:%S')
#     answer_result = qa({"question": query})    
#     answer = answer_result["answer"]    
#     return dt, query, sim1, sim2, sim3, answer
# conn = sqlite3.connect(path) 
# while True:    
#     query = input('질문 > ').strip()    
#     if not query:        break   
#     print(f'질문 : {query}')   
#     print('-' * 20)        
#     dt, query, sim1, sim2, sim3, answer = process_query(query)        
#     data = pd.DataFrame({'datetime': [dt],'query': [query],'sim1': [sim1],'sim2': [sim2],'sim3': [sim3],'answer': [answer]})        
#     data.to_sql('history', conn, if_exists='append', index=False)        
#     print(f'답변 : {answer}')    
#     print('=' * 50)
#     df = pd.read_sql('SELECT * FROM history', conn)
#     display(df)
#     conn.close()
# Out:
# 질문 : 나는 몇살이야?
# --------------------
# 답변 : 이에 대한 정보는 제가 알 수 없습니다.
# ==================================================
#    id             datetime                              query     sim1  \
# 0   1  2024-06-04 15:03:21   kt에이블 스쿨에 지원하고싶은데 어떤 조건들을 만족해야해?  0.23284
# 1   2  2024-06-04 15:03:55              내가 만약 취업상태라면 어떻게해야할까?  0.27547
# 2   3  2024-06-04 15:04:27  그러면 에이블스쿨에 학겨하기 전에 퇴사를 하면 참여가능할까?  0.21229
# 3   4  2024-06-04 16:08:36                           나는 26살이야  0.40889
# 4   5  2024-06-04 16:09:08                           나는 몇살이야?  0.38818
#
#       sim2     sim3                                             answer
# 0  0.24214  0.26018  KT 에이블스쿨은 미취업자를 대상으로 하며, 교육 시작일 기준으로 재직자는 지원이 ...
# 1  0.29558  0.30972  KT 에이블스쿨은 미취업자를 대상으로 하고 있어서, 현재 취업 상태일 경우에는 지원...
# 2  0.25994  0.26083  KT 에이블스쿨은 미취업자를 대상으로 하고, 교육 시작일 기준으로 재직자는 지원이 ...
# 3  0.42293  0.45180  네, 해당 교육 과정은 34세 이하의 지원 대상자를 대상으로 합니다. 다만, 35세...
# 4  0.39459  0.40453                             이에 대한 정보는 제가 알 수 없습니다.
# 질문 : 나는 26살이야
# --------------------
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[36], line 19
#      17 dt, query, sim1, sim2, sim3, answer = process_query(query)
#      18 data = pd.DataFrame({'datetime': [dt],'query': [query],'sim1': [sim1],'sim2': [sim2],'sim3': [sim3],'answer': [answer]})
# ---> 19 data.to_sql('history', conn, if_exists='append', index=False)
#      20 print(f'답변 : {answer}')
#      21 print('=' * 50)
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\io\sql.py:2850, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2839             raise ValueError(f"{col} ({my_type}) not a string")
#    2841 table = SQLiteTable(
#    2842     name,
#    2843     self,
#    (...)
#    2848     dtype=dtype,
#    2849 )
# -> 2850 table.create()
#    2851 return table.insert(chunksize, method)
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\io\sql.py:984, in SQLTable.create(self)
#     983 def create(self) -> None:
# --> 984     if self.exists():
#     985         if self.if_exists == "fail":
#     986             raise ValueError(f"Table '{self.name}' already exists.")
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\io\sql.py:970, in SQLTable.exists(self)
#     969 def exists(self):
# --> 970     return self.pd_sql.has_table(self.name, self.schema)
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\io\sql.py:2865, in SQLiteDatabase.has_table(self, name, schema)
#    2854 wld = "?"
#    2855 query = f"""
#    2856 SELECT
#    2857     name
#    (...)
#    2862     AND name={wld};
#    2863 """
# -> 2865 return len(self.execute(query, [name]).fetchall()) > 0
#
# File c:\Users\User\anaconda3\envs\qa_system\Lib\site-packages\pandas\io\sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2670     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2671 args = [] if params is None else [params]
# -> 2672 cur = self.con.cursor()
#    2673 try:
#    2674     cur.execute(sql, *args)
#
# ProgrammingError: Cannot operate on a closed database.
